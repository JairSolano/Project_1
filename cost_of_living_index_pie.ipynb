# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cost_of_livng_index = [{'Grocery':14.67, 'Housing': 27.97, 'Utilities': 8.75, 'Transportation': 10.75, 'Healthcare': 4.59,'Miscellaneous': 33.27}]
cost_of_livng_index
# Out:
# [{'Grocery': 14.67,
#   'Housing': 27.97,
#   'Utilities': 8.75,
#   'Transportation': 10.75,
#   'Healthcare': 4.59,
#   'Miscellaneous': 33.27}]

# %%
index = ["Grocery","Housing", "Utilities", "Transportation", "Healthcare", "Miscellaneous"]
index_value = [14.67,27.97,8.75,10.75,4.59,33.27]
colors = ["violet","red","orange","yellow","green","blue"]
explode = (0,0.2,0,0,0,0)

# %%
plt.pie(index_value, explode=explode, labels=index, colors=colors, autopct="%1.1f%%", shadow=True)
plt.savefig("COLI.png")
plt.show()
