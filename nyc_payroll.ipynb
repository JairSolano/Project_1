# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
city_pay_df = pd.read_csv("./nyc_affordability/Citywide_Payroll_Data__Fiscal_Year__20240608.csv")
city_pay_df.head()
# Out:
# C:\Users\solan\AppData\Local\Temp\ipykernel_29732\264688359.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   city_pay_df = pd.read_csv("./nyc_affordability/Citywide_Payroll_Data__Fiscal_Year__20240608.csv")
#    Fiscal Year  Payroll Number                     Agency Name  Last Name  \
# 0         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    BEREZIN
# 1         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     GEAGER
# 2         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     RAMANI
# 3         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT      ROTTA
# 4         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT  WILSON II
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0    MIKHAIL      NaN        08/10/2015              BROOKLYN
# 1   VERONICA        M        09/12/2016              BROOKLYN
# 2   SHRADDHA      NaN        02/22/2016              BROOKLYN
# ...

# %%
fiscal_city_pay = city_pay_df.loc[city_pay_df['Fiscal Year'] == 2021]
fiscal_city_pay = fiscal_city_pay.loc[fiscal_city_pay['Leave Status as of June 30'] == 'ACTIVE']
fiscal_city_pay = fiscal_city_pay.loc[fiscal_city_pay['Regular Hours'] >= 1664]
fiscal_city_pay = fiscal_city_pay.loc[fiscal_city_pay['Regular Gross Paid'] >= 1664]
fiscal_city_pay = fiscal_city_pay.loc[fiscal_city_pay['Agency Name'] != 'DEPARTMENT FOR THE AGING']

fiscal_city_pay = fiscal_city_pay[['Fiscal Year',
       'Agency Name',
       'Agency Start Date', 'Work Location Borough', 'Title Description',
       'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
       'Regular Hours', 'Regular Gross Paid']]
fiscal_city_pay.head()
# Out:
#         Fiscal Year                     Agency Name Agency Start Date  \
# 472160         2021           NYC HOUSING AUTHORITY        02/26/2018
# 472408         2021           NYC HOUSING AUTHORITY        08/12/2019
# 472554         2021   DEPT OF HEALTH/MENTAL HYGIENE        10/06/2014
# 472914         2021   DEPT OF HEALTH/MENTAL HYGIENE        02/26/2018
# 473743         2021  MAYORS OFFICE OF CONTRACT SVCS        10/10/2017
#
#        Work Location Borough         Title Description  \
# 472160             MANHATTAN        EXECUTIVE DIRECTOR
# 472408             MANHATTAN                     CHAIR
# 472554                QUEENS       STATIONARY ENGINEER
# 472914              BROOKLYN       STATIONARY ENGINEER
# 473743             MANHATTAN  COMPUTER SYSTEMS MANAGER
#
#        Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 472160                     ACTIVE     258000.0  per Annum         1820.0
# ...

# %%
fiscal_city_pay.to_csv("output_data/fiscal_2021.csv")

# %%
fiscal_city_pay_22 = city_pay_df.loc[city_pay_df['Fiscal Year'] == 2022]
fiscal_city_pay_22 = fiscal_city_pay_22.loc[fiscal_city_pay_22['Leave Status as of June 30'] == 'ACTIVE']
fiscal_city_pay_22 = fiscal_city_pay_22.loc[fiscal_city_pay_22['Regular Hours'] >= 1664]
fiscal_city_pay_22 = fiscal_city_pay_22.loc[fiscal_city_pay_22['Regular Gross Paid'] >= 1664]
fiscal_city_pay_22 = fiscal_city_pay_22.loc[fiscal_city_pay_22['Agency Name'] != 'DEPARTMENT FOR THE AGING']

fiscal_city_pay_22 = fiscal_city_pay_22[['Fiscal Year',
       'Agency Name',
       'Agency Start Date', 'Work Location Borough', 'Title Description',
       'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
       'Regular Hours', 'Regular Gross Paid']]
fiscal_city_pay_22.head()
# Out:
#        Fiscal Year            Agency Name Agency Start Date  \
# 5509          2022  NYC HOUSING AUTHORITY        10/28/2019
# 5658          2022  NYC HOUSING AUTHORITY        04/30/2012
# 5695          2022  NYC HOUSING AUTHORITY        11/25/2020
# 85138         2022  NYC HOUSING AUTHORITY        02/24/2020
# 91575         2022  NYC HOUSING AUTHORITY        12/03/2007
#
#       Work Location Borough         Title Description  \
# 5509               BROOKLYN                 CARETAKER
# 5658               BROOKLYN                 CARETAKER
# 5695               BROOKLYN                 CARETAKER
# 85138             MANHATTAN  EXECUTIVE AGENCY COUNSEL
# 91575                QUEENS               ELECTRICIAN
#
#       Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 5509                      ACTIVE     38557.00  per Annum         2160.0
# 5658                      ACTIVE     46278.00  per Annum         2160.0
# ...

# %%
fiscal_city_pay_22.to_csv("output_data/fiscal_2022.csv")

# %%
fiscal_city_pay_23 = city_pay_df.loc[city_pay_df['Fiscal Year'] == 2023]
fiscal_city_pay_23 = fiscal_city_pay_23.loc[fiscal_city_pay_23['Leave Status as of June 30'] == 'ACTIVE']
fiscal_city_pay_23 = fiscal_city_pay_23.loc[fiscal_city_pay_23['Regular Hours'] >= 1664]
fiscal_city_pay_23 = fiscal_city_pay_23.loc[fiscal_city_pay_23['Regular Gross Paid'] >= 1664]
fiscal_city_pay_23 = fiscal_city_pay_23.loc[fiscal_city_pay_23['Agency Name'] != 'DEPARTMENT FOR THE AGING']

fiscal_city_pay_23 = fiscal_city_pay_23[['Fiscal Year',
       'Agency Name',
       'Agency Start Date', 'Work Location Borough', 'Title Description',
       'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
       'Regular Hours', 'Regular Gross Paid']]
fiscal_city_pay_23.head()
# Out:
#          Fiscal Year          Agency Name Agency Start Date  \
# 5109775         2023  OFFICE OF THE MAYOR        04/26/2021
# 5109776         2023  OFFICE OF THE MAYOR        01/04/2022
# 5109780         2023  OFFICE OF THE MAYOR        01/01/2022
# 5109781         2023  OFFICE OF THE MAYOR        02/18/2020
# 5109783         2023  OFFICE OF THE MAYOR        01/03/2022
#
#         Work Location Borough         Title Description  \
# 5109775             MANHATTAN   RESEARCH PROJECTS COORD
# 5109776             MANHATTAN         SPECIAL ASSISTANT
# 5109780             MANHATTAN                     MAYOR
# 5109781             MANHATTAN                 SECRETARY
# 5109783             MANHATTAN  EXECUTIVE AGENCY COUNSEL
#
#         Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 5109775                     ACTIVE      70747.0  per Annum         1820.0
# 5109776                     ACTIVE      80651.0  per Annum         1820.0
# ...

# %%
fiscal_city_pay_23.to_csv("output_data/fiscal_2023.csv")

# %%
fiscal_city_pay_20 = city_pay_df.loc[city_pay_df['Fiscal Year'] == 2020]
fiscal_city_pay_20 = fiscal_city_pay_20.loc[fiscal_city_pay_20['Leave Status as of June 30'] == 'ACTIVE']
fiscal_city_pay_20 = fiscal_city_pay_20.loc[fiscal_city_pay_20['Regular Hours'] >= 1664]
fiscal_city_pay_20 = fiscal_city_pay_20.loc[fiscal_city_pay_20['Regular Gross Paid'] >= 1664]
fiscal_city_pay_20 = fiscal_city_pay_20.loc[fiscal_city_pay_20['Agency Name'] != 'DEPARTMENT FOR THE AGING']

fiscal_city_pay_20 = fiscal_city_pay_20[['Fiscal Year',
       'Agency Name',
       'Agency Start Date', 'Work Location Borough', 'Title Description',
       'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
       'Regular Hours', 'Regular Gross Paid']]
fiscal_city_pay_20.head()
# Out:
#    Fiscal Year                     Agency Name Agency Start Date  \
# 0         2020  OFFICE OF EMERGENCY MANAGEMENT        08/10/2015
# 1         2020  OFFICE OF EMERGENCY MANAGEMENT        09/12/2016
# 2         2020  OFFICE OF EMERGENCY MANAGEMENT        02/22/2016
# 3         2020  OFFICE OF EMERGENCY MANAGEMENT        09/16/2013
# 4         2020  OFFICE OF EMERGENCY MANAGEMENT        04/30/2018
#
#   Work Location Borough               Title Description  \
# 0              BROOKLYN  EMERGENCY PREPAREDNESS MANAGER
# 1              BROOKLYN  EMERGENCY PREPAREDNESS MANAGER
# 2              BROOKLYN  EMERGENCY PREPAREDNESS MANAGER
# 3              BROOKLYN  EMERGENCY PREPAREDNESS MANAGER
# 4              BROOKLYN  EMERGENCY PREPAREDNESS MANAGER
#
#   Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 0                     ACTIVE      86005.0  per Annum         1820.0
# 1                     ACTIVE      86005.0  per Annum         1820.0
# ...

# %%
fiscal_city_pay_19 = city_pay_df.loc[city_pay_df['Fiscal Year'] == 2019]
fiscal_city_pay_19 = fiscal_city_pay_19.loc[fiscal_city_pay_19['Leave Status as of June 30'] == 'ACTIVE']
fiscal_city_pay_19 = fiscal_city_pay_19.loc[fiscal_city_pay_19['Regular Hours'] >= 1664]
fiscal_city_pay_19 = fiscal_city_pay_19.loc[fiscal_city_pay_19['Regular Gross Paid'] >= 1664]
fiscal_city_pay_19 = fiscal_city_pay_19.loc[fiscal_city_pay_19['Agency Name'] != 'DEPARTMENT FOR THE AGING']

fiscal_city_pay_23 = fiscal_city_pay_23[['Fiscal Year',
       'Agency Name',
       'Agency Start Date', 'Work Location Borough', 'Title Description',
       'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
       'Regular Hours', 'Regular Gross Paid']]
fiscal_city_pay_19.head()
# Out:
#          Fiscal Year  Payroll Number          Agency Name  Last Name  \
# 3907282         2019             2.0  OFFICE OF THE MAYOR   FULEIHAN
# 3907283         2019             2.0  OFFICE OF THE MAYOR  DE BLASIO
# 3907284         2019             2.0  OFFICE OF THE MAYOR    PALACIO
# 3907285         2019             2.0  OFFICE OF THE MAYOR     ANGLIN
# 3907286         2019             2.0  OFFICE OF THE MAYOR   THOMPSON
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# 3907282       DEAN        A        12/31/2017             MANHATTAN
# 3907283       BILL      NaN        01/01/2014             MANHATTAN
# 3907284   HERMINIA      NaN        01/25/2016             MANHATTAN
# 3907285      LAURA        L        01/03/2017             MANHATTAN
# 3907286      JAMES        P        03/12/2018             MANHATTAN
#
#           Title Description Leave Status as of June 30  Base Salary  \
# 3907282  FIRST DEPUTY MAYOR                     ACTIVE     282659.0
# ...

# %%
avg_pay_23 = fiscal_city_pay_23['Regular Gross Paid'].mean()
avg_pay_22 = fiscal_city_pay_22['Regular Gross Paid'].mean()
avg_pay_21 = fiscal_city_pay['Regular Gross Paid'].mean()
avg_pay_20 = fiscal_city_pay_20['Regular Gross Paid'].mean()
avg_pay_19 = fiscal_city_pay_19['Regular Gross Paid'].mean()

# %%
x_value = ['2019','2020','2021','2022','2023']
y_value = [avg_pay_19,avg_pay_20,avg_pay_21,avg_pay_22,avg_pay_23]
plt.plot(x_value, y_value)
plt.title('Average NYC Employee Salary')
plt.xlabel('Years')
plt.ylabel('Salary (USD $)')
plt.savefig('avg_nyc_salary_2019_2023.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
avg_nyc_pay
# Out:
# [{'2019': 72822.07490757942,
#   '2020': 73771.01583443815,
#   '2021': 75300.57235498236,
#   '2022': 78884.37454766214,
#   '2023': 79648.82781984207}]
