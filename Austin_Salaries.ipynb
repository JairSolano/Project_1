# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress 
from scipy.stats import sem
import matplotlib.pyplot as plt
import requests
import json

# %%
texas_salary = pd.read_csv("./Texas Salary/2024-04-01.csv")
texas_salary.columns
# Out:
# C:\Users\solan\AppData\Local\Temp\ipykernel_29084\2305409674.py:1: DtypeWarning: Columns (12,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   texas_salary = pd.read_csv("./Texas Salary/2024-04-01.csv")
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'EMPLOYEE TYPE', 'HIRE EATE',
#        'RATE', 'HRSWKD', 'MONTHLY', 'ANNUAL', 'STATENUM', 'duplicated',
#        'multiple_full_time_jobs', 'combined_multiple_jobs', 'hide_from_search',
#        'summed_annual_salary'],
#       dtype='object')

# %%
texas_salary
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0        551.0  DEPARTMENT OF AGRICULTURE                     ...
# 1        101.0  SENATE                                        ...
# 2        529.0  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 3        241.0  COMPTROLLER'S - JUDICIARY                     ...
# 4        212.0  OFFICE OF COURT ADMINISTRATION                ...
# ...        ...                                                ...
# 149051     NaN                                                NaN
# 149052     NaN                                                NaN
# 149053     NaN                                                NaN
# 149054     NaN                                                NaN
# 149055     NaN                                                NaN
#
#                              LAST NAME                      FIRST NAME   MI  \
# 0       LONA                            MANUEL
# 1       KENNY                           PAT
# ...

# %%
tx_salary = texas_salary[['AGENCY NAME',
       'CLASS TITLE','EMPLOYEE TYPE',
       'RATE', 'HRSWKD', 'MONTHLY', 'ANNUAL',
       'summed_annual_salary']]

# %%
tx_salary['summed_annual_salary'].sum()
# Out:
# 1166320.2
